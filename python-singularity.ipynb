# %% [markdown]
# # Python Singularity (python2)
#
# ## [Output parameter documentation](https://docs.python.org/2/faq/programming.html#how-do-i-write-a-function-with-output-parameters-call-by-reference)

# %%
def f(l):
    assert len(l) != 0, "argument l should be not empty"
    l[0] = 1

# %%
l = [0,0,0]
f(l)
l
# Out:
# [1, 0, 0]

# %%
def f(x):
    x = 1

x = 0
f(1)
x
# Out:
# 0

# %% [markdown]
# ## [Scripting Language at last moment](https://youtu.be/tKTZoB2Vjuk?t=1856)

# %%
if 0 < 1: # always false
    error # this line is false but never executed, it works although it is false.
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-25-e0ab1a2f5d8b> in <module>()
#       1 if 0 < 1: # always false
# ----> 2     error # this line is false but never executed, it works although it is false.
#
# NameError: name 'error' is not defined

# %%
if 0 > 1: # always true
    error # here it is executed and the NameError exception is raised

# %% [markdown]
# * It is important to have a good code coverage for test.

# %% [markdown]
# ## [Tuple, List and comma for one element](https://wiki.python.org/moin/TupleSyntax)
#
# * tuple: `()` is immutable
# * list: `[]` is mutable

# %%
type(()) # empty tuple
# Out:
# tuple

# %%
type((1)) # /!\ it isn't a tuple
# Out:
# int

# %%
type((1,)) # /!\ tuple of one element
# Out:
# tuple

# %%
(1,) != (1) # (1) == 1 is int and (1,) is tuple such as len((1,)) == 1
# Out:
# True

# %%
[1,] == [1] # that is to say [1,] has length of 1.
# Out:
# True

# %%
type([]) # empty list
# Out:
# list

# %%
type([1]) == list # list of one element
# Out:
# True
